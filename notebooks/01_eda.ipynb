# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
import sys
sys.path.append('../src')
from data_cleaning import DataLoader  

loader = DataLoader('../data/raw/online_retail_II.xlsx')
df = loader.load_data()
df_clean = loader.clean_data()
# Out:
# Loaded 525461 rows
# Columns: ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer ID', 'Country']
#   Renamed: 'Invoice' → 'InvoiceNo'
#   Renamed: 'Customer ID' → 'CustomerID'
#   Renamed: 'Price' → 'UnitPrice'
# Removed 107927 rows with missing CustomerID
# Final clean dataset: 407661 rows, 4311 customers

# %%
# Load data
df = pd.read_excel('../data/raw/online_retail_II.xlsx', sheet_name='Year 2010-2011')

# %%
# Data cleaning (industry standard approach [^5^])
df = df.dropna(subset=['Customer ID'])
df = df[~df['Invoice'].str.contains('C', na=False)]  # Remove cancellations
df = df[(df['Quantity'] > 0) & (df['Price'] > 0)]
df['TotalAmount'] = df['Quantity'] * df['Price']
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
